# %% [markdown]
# # 神曲算法基础演示
# 5分钟体验对称性校准的威力

# %%
from shenqu import core
import matplotlib.pyplot as plt

# 生成演示数据
D = core.generate_demo_data(noise_level=0.05)
mismatch = core.calculate_symmetry_mismatch(D)
print(f"初始对称性失配度: {mismatch:.6f}")

# 可视化
plt.imshow(D, cmap='viridis')
plt.colorbar()
plt.title(f'Symmetry Mismatch 𝒟 = {mismatch:.4f}')
plt.show()
